# %%
# Dependencies
import json
import requests
# from config import api_key

# %%
# Config url api information
base_url = "http://en.wikipedia.org/w/api.php"

action = "query"
prop = "revisions"
titles = "List_of_Formula_One_circuits"
rvslots = "*"
rvprop = "content"
format = "json"
formatversion = "2"

query_url = f"{base_url}?action={action}&prop={prop}&titles={titles}&rvslots={rvslots}&rvprop={rvprop}&format={format}&formatversion={formatversion}"

# "https://en.wikipedia.org/wiki/List_of_Formula_One_circuits"

# %%
print(url)
# Out:
# http://en.wikipedia.org/w/api.php?action=query&prop=revisions&titles=List_of_Formula_One_circuits&rvslots*&rvpropcontent&formatversion2

# %%
# Get circuit data
circuit_response = requests.get(query_url)
circuit_json = circuit_response.json()

# Get the temperature from the response
print(f"The Wikipedia F1 Circuit API responded with: {circuit_json}.")
# Out:
# The Wikipedia F1 Circuit API responded with: {'batchcomplete': True, 'query': {'normalized': [{'fromencoded': False, 'from': 'List_of_Formula_One_circuits', 'to': 'List of Formula One circuits'}], 'pages': [{'pageid': 248995, 'ns': 0, 'title': 'List of Formula One circuits', 'revisions': [{'slots': {'main': {'contentmodel': 'wikitext', 'contentformat': 'text/x-wiki', 'content': '{{Short description|none}}\n{{Use dmy dates|date=October 2017}}\n[[File:Formula 1 all over the world.svg|thumb|upright=2|Locations of the circuits that hosted or are scheduled to host a Grand Prix. Nations on the current year\'s schedule are highlighted in green, with circuit locations marked in black. Former host nations are shown in dark grey. Former host circuits are marked with a white dot. \'\'De facto\'\' status of territories is shown.|alt=A map of the world showing the locations of the circuits that hosted or are scheduled to host a Grand Prix]]\n\n[[Formula One]], abbreviated to F1, is currently the 
# ...
