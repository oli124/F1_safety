# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# %%
# load in races csv file
csv_path = "../Resources/races.csv"
races_df = pd.read_csv(csv_path)
races_df.head()
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
#
#        time                                                url fp1_date  \
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...       \N
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...       \N
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...       \N
# 3  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...       \N
# 4  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...       \N
#
#   fp1_time fp2_date fp2_time fp3_date fp3_time quali_date quali_time  \
# 0       \N       \N       \N       \N       \N         \N         \N
# 1       \N       \N       \N       \N       \N         \N         \N
# 2       \N       \N       \N       \N       \N         \N         \N
# 3       \N       \N       \N       \N       \N         \N         \N
# 4       \N       \N       \N       \N       \N         \N         \N
#
#   sprint_date sprint_time
# 0          \N          \N
# 1          \N          \N
# 2          \N          \N
# 3          \N          \N
# 4          \N          \N

# %%
# load in results csv file
csv_path = "../Resources/results.csv"
results_df = pd.read_csv(csv_path)
results_df.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452         218.300         1
# 1         41    3       1:27.739         217.586         1
# 2         41    5       1:28.090         216.719         1
# 3         58    7       1:28.603         215.464         1
# 4         43    1       1:27.418         218.385         1

# %%
# load in status csv file
csv_path = "../Resources/status.csv"
status_df = pd.read_csv(csv_path)
status_df.head()
# Out:
#    statusId        status
# 0         1      Finished
# 1         2  Disqualified
# 2         3      Accident
# 3         4     Collision
# 4         5        Engine

# %%
# load in drivers csv file
csv_path = "../Resources/drivers.csv"
drivers_df = pd.read_csv(csv_path)
drivers_df.head()
# Out:
#    driverId   driverRef number code  forename     surname         dob  \
# 0         1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1         2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4         5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
# merge the status dataframe into the results dataframe
merged_res_stat_df = pd.merge(results_df, status_df, on=['statusId'])
merged_res_stat_df.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId    status
# 0         39    2       1:27.452         218.300         1  Finished
# 1         41    3       1:27.739         217.586         1  Finished
# 2         41    5       1:28.090         216.719         1  Finished
# 3         58    7       1:28.603         215.464         1  Finished
# 4         43    1       1:27.418         218.385         1  Finished

# %%
# merge the races dataframe into the merged_res_stat dataframe
merged_df = pd.merge(merged_res_stat_df, races_df, on=['raceId'])
merged_df.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  ...  fp1_date fp1_time fp2_date  \
# 0            1              1    10.0  ...        \N       \N       \N
# 1            2              2     8.0  ...        \N       \N       \N
# 2            3              3     6.0  ...        \N       \N       \N
# 3            4              4     5.0  ...        \N       \N       \N
# 4            5              5     4.0  ...        \N       \N       \N
#
#   fp2_time fp3_date fp3_time quali_date  quali_time sprint_date  sprint_time
# 0       \N       \N       \N         \N          \N          \N           \N
# 1       \N       \N       \N         \N          \N          \N           \N
# 2       \N       \N       \N         \N          \N          \N           \N
# 3       \N       \N       \N         \N          \N          \N           \N
# 4       \N       \N       \N         \N          \N          \N           \N
#
# [5 rows x 36 columns]

# %%
# merge the drivers dataframe into the merged dataframe
fully_merged_df = pd.merge(merged_df, drivers_df, on=['driverId'])
fully_merged_df.head()
# Out:
#    resultId  raceId  driverId  constructorId number_x  grid position  \
# 0         1      18         1              1       22     1        1
# 1        27      19         1              1       22     9        5
# 2        57      20         1              1       22     3       13
# 3        69      21         1              1       22     5        3
# 4        90      22         1              1       22     3        2
#
#   positionText  positionOrder  points  ...  sprint_date sprint_time driverRef  \
# 0            1              1    10.0  ...           \N          \N  hamilton
# 1            5              5     4.0  ...           \N          \N  hamilton
# 2           13             13     0.0  ...           \N          \N  hamilton
# 3            3              3     6.0  ...           \N          \N  hamilton
# 4            2              2     8.0  ...           \N          \N  hamilton
#
#   number_y code forename   surname         dob nationality  \
# 0       44  HAM    Lewis  Hamilton  1985-01-07     British
# 1       44  HAM    Lewis  Hamilton  1985-01-07     British
# 2       44  HAM    Lewis  Hamilton  1985-01-07     British
# 3       44  HAM    Lewis  Hamilton  1985-01-07     British
# 4       44  HAM    Lewis  Hamilton  1985-01-07     British
#
#                                          url_y
# 0  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 2  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 3  http://en.wikipedia.org/wiki/Lewis_Hamilton
# 4  http://en.wikipedia.org/wiki/Lewis_Hamilton
#
# [5 rows x 44 columns]

# %%
# save merged file to csv
fully_merged_df.to_csv('../fully_merged2.csv', index=True)

# %%
# create copy of merged dataframe and sort by year
# create a new dataframe to store resultId, raceId, driverId, statusId, status and date
id_df = fully_merged_df[['year','round','raceId','resultId','driverId','forename', 'surname','statusId','status']].copy().sort_values(by=['year','round'])
id_df.head(40)
# Out:
#        year  round  raceId  resultId  driverId      forename         surname  \
# 21514  1950      1     833     20036       579          Juan          Fangio
# 21620  1950      1     833     20042       589         Louis          Chiron
# 21754  1950      1     833     20030       619           Bob          Gerard
# 21811  1950      1     833     20029       627         Louis          Rosier
# 21946  1950      1     833     20041       640         Toulo  de Graffenried
# 21999  1950      1     833     20025       642          Nino          Farina
# 22161  1950      1     833     20035       660        Johnny           Claes
# 22170  1950      1     833     20044       661         Peter          Walker
# 22173  1950      1     833     20178       666          Tony            Rolt
# 22232  1950      1     833     20038       669        Prince            Bira
# 22278  1950      1     833     20027       686           Reg         Parnell
# 22362  1950      1     833     20028       704          Yves       Cabantous
# 22450  1950      1     833     20032       741      Philippe       Étancelin
# 22460  1950      1     833     20039       747         David          Murray
# 22528  1950      1     833     20026       786         Luigi         Fagioli
# 22541  1950      1     833     20037       776           Joe           Kelly
# 22543  1950      1     833     20034       778         Brian    Shawe Taylor
# 22550  1950      1     833     20040       785         Geoff        Crossley
# 22552  1950      1     833     20031       787          Cuth        Harrison
# 22555  1950      1     833     20043       789        Eugène          Martin
# 22557  1950      1     833     20033       784         David       Hampshire
# 22559  1950      1     833     20177       788           Joe             Fry
# 22560  1950      1     833     20045       790        Leslie         Johnson
# 20334  1950      2     834     20061       427       Maurice     Trintignant
# 20941  1950      2     834     20055       498  José Froilán        González
# 21005  1950      2     834     20064       501         Harry          Schell
# 21515  1950      2     834     20046       579          Juan          Fangio
# 21621  1950      2     834     20048       589         Louis          Chiron
# 21755  1950      2     834     20051       619           Bob          Gerard
# 21812  1950      2     834     20058       627         Louis          Rosier
# 21844  1950      2     834     20059       626        Robert          Manzon
# 21920  1950      2     834     20053       633         Luigi       Villoresi
# 21947  1950      2     834     20060       640         Toulo  de Graffenried
# 22000  1950      2     834     20056       642          Nino          Farina
# 22045  1950      2     834     20047       647       Alberto          Ascari
# 22162  1950      2     834     20052       660        Johnny           Claes
# 22233  1950      2     834     20050       669        Prince            Bira
# 22295  1950      2     834     20065       687         Peter       Whitehead
# 22451  1950      2     834     20054       741      Philippe       Étancelin
# 22493  1950      2     834     20063       762        Franco             Rol
#
#        statusId          status
# 21514        44        Oil leak
# 21620         8          Clutch
# 21754        13         +3 Laps
# 21811        12         +2 Laps
# 21946         5          Engine
# 21999         1        Finished
# 22161        16         +6 Laps
# 22170         6         Gearbox
# 22173         6         Gearbox
# 22232        60     Out of fuel
# 22278         1        Finished
# 22362        12         +2 Laps
# 22450        15         +5 Laps
# 22460         5          Engine
# 22528         1        Finished
# 22541        62  Not classified
# 22543        16         +6 Laps
# 22550         7    Transmission
# 22552        13         +3 Laps
# 22555        51    Oil pressure
# 22557        16         +6 Laps
# 22559        16         +6 Laps
# 22560       126    Supercharger
# 20334         3        Accident
# 20941         3        Accident
# 21005         4       Collision
# 21515         1        Finished
# 21621        12         +2 Laps
# 21755        16         +6 Laps
# 21812         3        Accident
# 21844         3        Accident
# 21920       109            Axle
# 21947         3        Accident
# 22000         3        Accident
# 22045        11          +1 Lap
# 22162        16         +6 Laps
# 22233        15         +5 Laps
# 22295         5          Engine
# 22451        44        Oil leak
# 22493         3        Accident

# %%
# find the total number of drivers in each round per season
entrants_df = id_df.groupby(by=['year','round']).size().reset_index(name='sum entrants')
entrants_df.head(20)
# Out:
#     year  round  sum entrants
# 0   1950      1            23
# 1   1950      2            21
# 2   1950      3            35
# 3   1950      4            18
# 4   1950      5            14
# 5   1950      6            20
# 6   1950      7            29
# 7   1951      1            21
# 8   1951      2            34
# 9   1951      3            13
# 10  1951      4            26
# 11  1951      5            20
# 12  1951      6            22
# 13  1951      7            23
# 14  1951      8            20
# 15  1952      1            22
# 16  1952      2            33
# 17  1952      3            22
# 18  1952      4            22
# 19  1952      5            32

# %%
# create dataframe with the row information from columns
select_df = id_df['status'].isin(['Injury', 'Injured','Eye injury'])
injured_df = id_df.loc[select_df]
injured_df
# Out:
#        year  round  raceId  resultId  driverId    forename      surname  \
# 19912  1966      6     695     16924       389         Guy       Ligier
# 18655  1972      6     625     15464       337      Helmut        Marko
# 14207  1977      5     547     13363       182        Niki        Lauda
# 13828  1982     14     480     11481       175     Patrick       Tambay
# 8798   1985      7     426      9997        95       Nigel      Mansell
# 11337  1987      2     389      9037       137      Nelson       Piquet
# 10755  1988      6     377      8674       122        Ivan      Capelli
# 11960  1990     14     334      7486       151      Martin     Donnelly
# 7317   1993     12     284      5894        70  Alessandro      Zanardi
# 4122   1994      3     259      5221        22      Rubens  Barrichello
# 8269   1994      4     260      5248        91        Karl   Wendlinger
# 8136   1994      5     261      5275        85      Andrea   Montermini
# 6761   1995     17     256      5138        57        Mika     Häkkinen
# 8114   1996      6     229      4512        85      Andrea   Montermini
# 7877   1997     16     222      4358        81      Gianni   Morbidelli
# 6995   1998      2     192      3688        65      Johnny      Herbert
# 3168   2002     11     134      2435        21   Giancarlo   Fisichella
# 6273   2002     17     140      2556        66       Allan       McNish
# 2513   2003      7     114      2014        18      Jenson       Button
# 3319   2009     15      15      7853        10        Timo        Glock
# 23054  2011      6     846     23541       815      Sergio        Pérez
#
#        statusId      status
# 19912        82      Injury
# 18655       107  Eye injury
# 14207        73     Injured
# 13828        82      Injury
# 8798         82      Injury
# 11337        82      Injury
# 10755        73     Injured
# 11960        73     Injured
# 7317         82      Injury
# 4122         82      Injury
# 8269         82      Injury
# 8136         82      Injury
# 6761         73     Injured
# 8114         82      Injury
# 7877         82      Injury
# 6995         82      Injury
# 3168         82      Injury
# 6273         73     Injured
# 2513         73     Injured
# 3319         73     Injured
# 23054        82      Injury

# %%
# create a copy of the inujured_df dataframe and convert the statusID column values to '1'
statusId_df = injured_df.copy()
statusId_df['statusId'].replace([82,73,107],1,inplace=True)
statusId_df
# Out:
#        year  round  raceId  resultId  driverId    forename      surname  \
# 19912  1966      6     695     16924       389         Guy       Ligier
# 18655  1972      6     625     15464       337      Helmut        Marko
# 14207  1977      5     547     13363       182        Niki        Lauda
# 13828  1982     14     480     11481       175     Patrick       Tambay
# 8798   1985      7     426      9997        95       Nigel      Mansell
# 11337  1987      2     389      9037       137      Nelson       Piquet
# 10755  1988      6     377      8674       122        Ivan      Capelli
# 11960  1990     14     334      7486       151      Martin     Donnelly
# 7317   1993     12     284      5894        70  Alessandro      Zanardi
# 4122   1994      3     259      5221        22      Rubens  Barrichello
# 8269   1994      4     260      5248        91        Karl   Wendlinger
# 8136   1994      5     261      5275        85      Andrea   Montermini
# 6761   1995     17     256      5138        57        Mika     Häkkinen
# 8114   1996      6     229      4512        85      Andrea   Montermini
# 7877   1997     16     222      4358        81      Gianni   Morbidelli
# 6995   1998      2     192      3688        65      Johnny      Herbert
# 3168   2002     11     134      2435        21   Giancarlo   Fisichella
# 6273   2002     17     140      2556        66       Allan       McNish
# 2513   2003      7     114      2014        18      Jenson       Button
# 3319   2009     15      15      7853        10        Timo        Glock
# 23054  2011      6     846     23541       815      Sergio        Pérez
#
#        statusId      status
# 19912         1      Injury
# 18655         1  Eye injury
# 14207         1     Injured
# 13828         1      Injury
# 8798          1      Injury
# 11337         1      Injury
# 10755         1     Injured
# 11960         1     Injured
# 7317          1      Injury
# 4122          1      Injury
# 8269          1      Injury
# 8136          1      Injury
# 6761          1     Injured
# 8114          1      Injury
# 7877          1      Injury
# 6995          1      Injury
# 3168          1      Injury
# 6273          1     Injured
# 2513          1     Injured
# 3319          1     Injured
# 23054         1      Injury

# %%
# merge the entrants dataframe with the injured dataframe
injury_racers_df = pd.merge(entrants_df, injured_df, on=['year','round'], how= 'left')
injury_racers_df
# Out:
#       year  round  sum entrants  raceId  resultId  driverId forename surname  \
# 0     1950      1            23     NaN       NaN       NaN      NaN     NaN
# 1     1950      2            21     NaN       NaN       NaN      NaN     NaN
# 2     1950      3            35     NaN       NaN       NaN      NaN     NaN
# 3     1950      4            18     NaN       NaN       NaN      NaN     NaN
# 4     1950      5            14     NaN       NaN       NaN      NaN     NaN
# ...    ...    ...           ...     ...       ...       ...      ...     ...
# 1074  2022     18            20     NaN       NaN       NaN      NaN     NaN
# 1075  2022     19            20     NaN       NaN       NaN      NaN     NaN
# 1076  2022     20            20     NaN       NaN       NaN      NaN     NaN
# 1077  2022     21            20     NaN       NaN       NaN      NaN     NaN
# 1078  2022     22            20     NaN       NaN       NaN      NaN     NaN
#
#       statusId status
# 0          NaN    NaN
# 1          NaN    NaN
# 2          NaN    NaN
# 3          NaN    NaN
# 4          NaN    NaN
# ...        ...    ...
# 1074       NaN    NaN
# 1075       NaN    NaN
# 1076       NaN    NaN
# 1077       NaN    NaN
# 1078       NaN    NaN
#
# [1079 rows x 10 columns]

# %%
injury_racers_df['statusId'].replace([82,73,107],1,inplace=True)
injury_racers_df
# Out:
#       year  round  sum entrants  raceId  resultId  driverId forename surname  \
# 0     1950      1            23     NaN       NaN       NaN      NaN     NaN
# 1     1950      2            21     NaN       NaN       NaN      NaN     NaN
# 2     1950      3            35     NaN       NaN       NaN      NaN     NaN
# 3     1950      4            18     NaN       NaN       NaN      NaN     NaN
# 4     1950      5            14     NaN       NaN       NaN      NaN     NaN
# ...    ...    ...           ...     ...       ...       ...      ...     ...
# 1074  2022     18            20     NaN       NaN       NaN      NaN     NaN
# 1075  2022     19            20     NaN       NaN       NaN      NaN     NaN
# 1076  2022     20            20     NaN       NaN       NaN      NaN     NaN
# 1077  2022     21            20     NaN       NaN       NaN      NaN     NaN
# 1078  2022     22            20     NaN       NaN       NaN      NaN     NaN
#
#       statusId status
# 0          NaN    NaN
# 1          NaN    NaN
# 2          NaN    NaN
# 3          NaN    NaN
# 4          NaN    NaN
# ...        ...    ...
# 1074       NaN    NaN
# 1075       NaN    NaN
# 1076       NaN    NaN
# 1077       NaN    NaN
# 1078       NaN    NaN
#
# [1079 rows x 10 columns]

# %%
injury_racers_df.to_csv('../drivers.csv', index=True)

# %%
# replace any NaN entries in the statusID column with a '0'
injury_racers_df['statusId'].fillna(0, inplace= True)
injury_racers_df
# Out:
#       year  round  sum entrants  raceId  resultId  driverId forename surname  \
# 0     1950      1            23     NaN       NaN       NaN      NaN     NaN
# 1     1950      2            21     NaN       NaN       NaN      NaN     NaN
# 2     1950      3            35     NaN       NaN       NaN      NaN     NaN
# 3     1950      4            18     NaN       NaN       NaN      NaN     NaN
# 4     1950      5            14     NaN       NaN       NaN      NaN     NaN
# ...    ...    ...           ...     ...       ...       ...      ...     ...
# 1074  2022     18            20     NaN       NaN       NaN      NaN     NaN
# 1075  2022     19            20     NaN       NaN       NaN      NaN     NaN
# 1076  2022     20            20     NaN       NaN       NaN      NaN     NaN
# 1077  2022     21            20     NaN       NaN       NaN      NaN     NaN
# 1078  2022     22            20     NaN       NaN       NaN      NaN     NaN
#
#       statusId status
# 0          0.0    NaN
# 1          0.0    NaN
# 2          0.0    NaN
# 3          0.0    NaN
# 4          0.0    NaN
# ...        ...    ...
# 1074       0.0    NaN
# 1075       0.0    NaN
# 1076       0.0    NaN
# 1077       0.0    NaN
# 1078       0.0    NaN
#
# [1079 rows x 10 columns]

# %%
# in the injured column convert values from float to integers
injury_racers_df['statusId'] = injury_racers_df['statusId'].astype(int)
injury_racers_df
# Out:
#       year  round  sum entrants  raceId  resultId  driverId forename surname  \
# 0     1950      1            23     NaN       NaN       NaN      NaN     NaN
# 1     1950      2            21     NaN       NaN       NaN      NaN     NaN
# 2     1950      3            35     NaN       NaN       NaN      NaN     NaN
# 3     1950      4            18     NaN       NaN       NaN      NaN     NaN
# 4     1950      5            14     NaN       NaN       NaN      NaN     NaN
# ...    ...    ...           ...     ...       ...       ...      ...     ...
# 1074  2022     18            20     NaN       NaN       NaN      NaN     NaN
# 1075  2022     19            20     NaN       NaN       NaN      NaN     NaN
# 1076  2022     20            20     NaN       NaN       NaN      NaN     NaN
# 1077  2022     21            20     NaN       NaN       NaN      NaN     NaN
# 1078  2022     22            20     NaN       NaN       NaN      NaN     NaN
#
#       statusId status
# 0            0    NaN
# 1            0    NaN
# 2            0    NaN
# 3            0    NaN
# 4            0    NaN
# ...        ...    ...
# 1074         0    NaN
# 1075         0    NaN
# 1076         0    NaN
# 1077         0    NaN
# 1078         0    NaN
#
# [1079 rows x 10 columns]

# %%
injury_racers_df = injury_racers_df.rename(columns={'sum entrants': 'total drivers', 'statusId': 'injured'})
injury_racers_df
# Out:
#       year  round  total drivers  raceId  resultId  driverId forename surname  \
# 0     1950      1             23     NaN       NaN       NaN      NaN     NaN
# 1     1950      2             21     NaN       NaN       NaN      NaN     NaN
# 2     1950      3             35     NaN       NaN       NaN      NaN     NaN
# 3     1950      4             18     NaN       NaN       NaN      NaN     NaN
# 4     1950      5             14     NaN       NaN       NaN      NaN     NaN
# ...    ...    ...            ...     ...       ...       ...      ...     ...
# 1074  2022     18             20     NaN       NaN       NaN      NaN     NaN
# 1075  2022     19             20     NaN       NaN       NaN      NaN     NaN
# 1076  2022     20             20     NaN       NaN       NaN      NaN     NaN
# 1077  2022     21             20     NaN       NaN       NaN      NaN     NaN
# 1078  2022     22             20     NaN       NaN       NaN      NaN     NaN
#
#       injured status
# 0           0    NaN
# 1           0    NaN
# 2           0    NaN
# 3           0    NaN
# 4           0    NaN
# ...       ...    ...
# 1074        0    NaN
# 1075        0    NaN
# 1076        0    NaN
# 1077        0    NaN
# 1078        0    NaN
#
# [1079 rows x 10 columns]

# %%
# create plot chart
injury_racers_df.plot(x='year', y=['total drivers', 'injured'])

#Add labels and title
plt.xlabel('Year')
plt.ylabel('Driver Entrants per Round')
plt.title('Driver Injuries vs. Competing Drivers in Formula One Races');

# save the chart
plt.savefig('../Visualisations/injured_vs_drivers.png')

# %%
total_injured = injury_racers_df['injured'].sum()
total_drivers = injury_racers_df['total drivers'].sum()
print(total_injured)
print(total_drivers)
# Out:
# 21
# 25840

# %%
races_per_year = injury_racers_df['year'].value_counts()
races_per_year
# Out:
# 2022    22
# 2021    22
# 2019    21
# 2018    21
# 2016    21
#         ..
# 1961     8
# 1952     8
# 1951     8
# 1955     7
# 1950     7
# Name: year, Length: 73, dtype: int64

# %%
sum_of_races = races_per_year.sum()
sum_of_races
# Out:
# 1079

# %% [markdown]
# # OBSERVATIONS
#
# In total there have been 25,840 entrants (total drivers) across 1,079 races and only 21 recorded injuries across the 73 seasons of Formula One.
#
# Through the 1950's and 1960's, the number of drivers entered into races varied widely from the mid teens upto a high of 55 in one race event in 1954. Since the mid 90's driver numbers have been normalised to the mid to low 20's per race event.
#
# The number of drivers entered in races bares no correlation to the number of injuries to drivers over the 73 seasons of Formula One.
#
# This data does not include qualifying or practice sessions nor any test events
